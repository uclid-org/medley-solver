# %%
import csv, os, numpy as np, matplotlib.pyplot as plt, random

from scipy.stats import describe
from plotting import *

# %%
a, b, c = run_all('bv', "BV")
# Out:
# Number of differences between machsmt & optimal:  19
# Number of differences between medley & optimal:  288
# diff between med/mach 1888.7961087226868 1593.6174080371857 772.5197360515594
# Medley solved:  287
# Machsmt solved:  287
# Best possible solved:  294

# %%
a, b, c = run_all('sage2', "Sage2")
# Out:
# Number of differences between machsmt & optimal:  135
# Number of differences between medley & optimal:  229
# diff between med/mach 17697.698785305023 12825.435355424881 11070.35207605362
# Medley solved:  167
# Machsmt solved:  210
# Best possible solved:  227

# %%
a, b, c = run_all('uclid', "uclid")
# Out:
# Number of differences between machsmt & optimal:  4
# Number of differences between medley & optimal:  250
# diff between med/mach 3296.127345085144 1662.4050161838531 1474.330426454544
# Medley solved:  285
# Machsmt solved:  290
# Best possible solved:  292

# %%
a, b, c = run_all('qf_abv', "QF_ABV")
# Out:
# Number of differences between machsmt & optimal:  221
# Number of differences between medley & optimal:  288
# diff between med/mach 601.6981449127197 501.56105279922485 331.7342166900635
# Medley solved:  297
# Machsmt solved:  297
# Best possible solved:  298

# %%
a, b, c = run_all('combined', 'combined')
# Out:
# Number of differences between machsmt & optimal:  392
# Number of differences between medley & optimal:  1077
# diff between med/mach 22734.006418323515 17396.19103193283 14486.305998325348
# Medley solved:  1050
# Machsmt solved:  1077
# Best possible solved:  1104

# %%
var_plotter("var_files/BV", "BV")
# Out:
# Best Solver:  Z3

# %%
var_plotter("var_files/QF_ABV", "QF_ABV")
# Out:
# Best Solver:  Bitwuzla

# %%
var_plotter("var_files/Sage2", "Sage2")
# Out:
# Best Solver:  Bitwuzla

# %%
var_plotter("var_files/uclid", "uclid")
# Out:
# Best Solver:  Z3

# %%
var_plotter("var_files/combined", "combined")
# Out:
# Best Solver:  Z3
